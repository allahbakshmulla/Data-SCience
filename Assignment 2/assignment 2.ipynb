# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('imdb_top_250_movies.csv')

# %%
data
# Out:
#      place               movie_title    rating  year  \
# 0        1  The Shawshank Redemption  9.233807  1994
# 1        2             The Godfather  9.155795  1972
# 2        3           The Dark Knight  8.985098  2008
# 3        4    The Godfather: Part II  8.983870  1974
# 4        5              12 Angry Men  8.947338  1957
# ..     ...                       ...       ...   ...
# 245    246                   Aladdin  8.007108  1992
# 246    247                    Gandhi  8.007059  1982
# 247    248                  The Help  8.004875  2011
# 248    249      Beauty and the Beast  8.003484  1991
# 249    250        Dances with Wolves  8.001762  1990
#
#                                              star_cast
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...
# 2    Christopher Nolan (dir.), Christian Bale, Heat...
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...
# ...

# %%
sorted=data.sort_values(by=['rating'],ascending=False)

# %%
sorted
# Out:
#      place               movie_title    rating  year  \
# 0        1  The Shawshank Redemption  9.233807  1994
# 1        2             The Godfather  9.155795  1972
# 2        3           The Dark Knight  8.985098  2008
# 3        4    The Godfather: Part II  8.983870  1974
# 4        5              12 Angry Men  8.947338  1957
# ..     ...                       ...       ...   ...
# 245    246                   Aladdin  8.007108  1992
# 246    247                    Gandhi  8.007059  1982
# 247    248                  The Help  8.004875  2011
# 248    249      Beauty and the Beast  8.003484  1991
# 249    250        Dances with Wolves  8.001762  1990
#
#                                              star_cast
# 0    Frank Darabont (dir.), Tim Robbins, Morgan Fre...
# 1    Francis Ford Coppola (dir.), Marlon Brando, Al...
# 2    Christopher Nolan (dir.), Christian Bale, Heat...
# 3    Francis Ford Coppola (dir.), Al Pacino, Robert...
# ...

# %%
rating = list()

# %%
rating = sorted['rating'].tolist()

# %%
rating
# Out:
# [9.233807254585242,
#  9.15579542282764,
#  8.98509805446809,
#  8.98386962382605,
#  8.947337809482658,
#  8.935094668950807,
#  8.920740022489651,
#  8.850900043441882,
#  8.803405488491403,
#  8.793881570281913,
#  8.76721645601354,
#  8.750234079677616,
#  8.732887982123787,
#  8.727577244062848,
#  8.70176010075839,
#  8.671116383973743,
#  8.651280840738016,
#  8.64139533714702,
#  8.60389417048204,
#  8.599224307413667,
#  8.596981634324576,
#  8.587998367462582,
#  8.578963349111989,
#  8.577535411132475,
#  8.566060405342311,
#  8.559628788970988,
#  8.55483575513749,
#  8.554486296783107,
#  8.534939031464944,
#  8.517969161450774,
#  8.515381893317013,
#  8.50873249824614,
#  8.50449898544185,
#  8.500950744062882,
#  8.495539253807179,
#  8.488466547935333,
#  8.485247155112784,
#  8.484759585480596,
#  8.476721330206313,
#  8.474964953344136,
#  8.467917084900462,
#  8.46571707500824,
#  8.459725087493265,
#  8.454115561221561,
#  8.449986112262314,
# ...

# %%
names = sorted['movie_title'].tolist()

# %%
names
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Dark Knight',
#  'The Godfather: Part II',
#  '12 Angry Men',
#  "Schindler's List",
#  'The Lord of the Rings: The Return of the King',
#  'Pulp Fiction',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  ' Il buono, il brutto, il cattivo',
#  'Forrest Gump',
#  'Fight Club',
#  'Inception',
#  'The Lord of the Rings: The Two Towers',
#  'The Empire Strikes Back',
#  'The Matrix',
#  'Goodfellas',
#  "One Flew Over the Cuckoo's Nest",
#  'Se7en',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'The Silence of the Lambs',
#  'Cidade de Deus',
#  'Saving Private Ryan',
#  'La vita è bella',
#  'The Green Mile',
#  'Interstellar',
#  'Star Wars',
#  'Terminator 2: Judgment Day',
#  'Back to the Future',
#  'Sen to Chihiro no kamikakushi',
#  'Psycho',
#  'The Pianist',
#  'Léon',
#  'Gisaengchung',
#  'The Lion King',
#  'Gladiator',
#  'American History X',
#  'The Usual Suspects',
#  'The Departed',
# ...

# %%
topMovies=list()
theirRating=list()

# %%
for i in range(10):
    topMovies.append(names[i])
    theirRating.append(rating[i])

# %%
topMovies,theirRating
# Out:
# (['The Shawshank Redemption',
#   'The Godfather',
#   'The Dark Knight',
#   'The Godfather: Part II',
#   '12 Angry Men',
#   "Schindler's List",
#   'The Lord of the Rings: The Return of the King',
#   'Pulp Fiction',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   ' Il buono, il brutto, il cattivo'],
#  [9.233807254585242,
#   9.15579542282764,
#   8.98509805446809,
#   8.98386962382605,
#   8.947337809482658,
#   8.935094668950807,
#   8.920740022489651,
#   8.850900043441882,
#   8.803405488491403,
#   8.793881570281913])

# %%
plt.xlabel('Movie name')
plt.ylabel('Rating')
plt.barh(topMovies,theirRating)
plt.savefig('result.png')
